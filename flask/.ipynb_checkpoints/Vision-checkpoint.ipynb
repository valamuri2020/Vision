# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('2018_data.csv')
df.head(5)
# Out:
# C:\Users\salam\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (9,1725,1726,1727,1728,1729,1743,1815,1816,1817,1818,1823,1824,1830,1831,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1909,1910,1911,1912,1913,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1983,1984,2376,2377) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# ...

# %%
df.columns
# Out:
# Index(['UNITID', 'OPEID', 'OPEID6', 'INSTNM', 'CITY', 'STABBR', 'ZIP',
#        'ACCREDAGENCY', 'INSTURL', 'NPCURL',
#        ...
#        'BBRR2_FED_UGCOMP_MAKEPROG_SUPP', 'BBRR2_FED_UGCOMP_PAIDINFULL_SUPP',
#        'BBRR2_FED_UGCOMP_DISCHARGE_SUPP', 'LPSTAFFORD_CNT', 'LPSTAFFORD_AMT',
#        'LPPPLUS_CNT', 'LPPPLUS_AMT', 'LPGPLUS_CNT', 'LPGPLUS_AMT', 'FEDSCHCD'],
#       dtype='object', length=2383)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6806 entries, 0 to 6805
# Columns: 2383 entries, UNITID to FEDSCHCD
# dtypes: float64(1977), int64(14), object(392)
# memory usage: 123.7+ MB

# %%
df.describe()
# Out:
#              UNITID         OPEID        OPEID6  SCH_DEG         HCM2  \
# count  6.806000e+03  6.806000e+03   6806.000000      0.0  6806.000000
# mean   2.126810e+06  1.784672e+06  16671.262269      NaN     0.007934
# std    7.640544e+06  2.739965e+06  14847.499904      NaN     0.088726
# min    1.006540e+05  1.002000e+05   1002.000000      NaN     0.000000
# 25%    1.740315e+05  3.119500e+05   3109.250000      NaN     0.000000
# 50%    2.282095e+05  1.019812e+06  10198.000000      NaN     0.000000
# 75%    4.527585e+05  3.034350e+06  30273.750000      NaN     0.000000
# max    4.914640e+07  8.209888e+07  42788.000000      NaN     1.000000
#
#               MAIN    NUMBRANCH      PREDDEG      HIGHDEG      CONTROL  ...  \
# count  6806.000000  6806.000000  6806.000000  6806.000000  6806.000000  ...
# mean      0.785336     3.523509     1.833823     2.222892     2.087570  ...
# std       0.410619     8.751410     1.070275     1.362394     0.835281  ...
# ...

# %%
df_reduced = df[['UNITID', 'OPEID6', 'INSTNM', 'CITY', 'STABBR', 'ZIP', 'INSTURL', 'NPCURL', 'ADM_RATE_ALL', 'ACTCMMID', 'ACTENMID', 'ACTMTMID', 'SAT_AVG_ALL']]

# %%
df_reduced.head(5)
# Out:
#    UNITID  OPEID6                               INSTNM        CITY STABBR  \
# 0  100654    1002             Alabama A & M University      Normal     AL
# 1  100663    1052  University of Alabama at Birmingham  Birmingham     AL
# 2  100690   25034                   Amridge University  Montgomery     AL
# 3  100706    1055  University of Alabama in Huntsville  Huntsville     AL
# 4  100724    1005             Alabama State University  Montgomery     AL
#
#           ZIP                    INSTURL  \
# 0       35762              www.aamu.edu/
# 1  35294-0110        https://www.uab.edu
# 2  36117-3553  www.amridgeuniversity.edu
# 3       35899                www.uah.edu
# 4  36104-0271              www.alasu.edu
#
#                                               NPCURL  ADM_RATE_ALL  ACTCMMID  \
# 0  www.aamu.edu/admissions-aid/tuition-fees/net-p...        0.8986      18.0
# 1   https://uab.studentaidcalculator.com/survey.aspx        0.9211      25.0
# ...

# %%
sns.set_style('whitegrid')

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_reduced.isnull(), cmap='viridis', yticklabels=False, cbar=False)
# Out:
# <AxesSubplot:>

# %%
percent_missing = df_reduced.isnull().sum() * 100 / len(df)
percent_missing.sort_values(axis=0)
# Out:
# UNITID           0.000000
# OPEID6           0.000000
# INSTNM           0.000000
# CITY             0.000000
# STABBR           0.000000
# ZIP              0.000000
# INSTURL          0.440788
# NPCURL           7.772554
# ADM_RATE_ALL    67.058478
# SAT_AVG_ALL     79.047899
# ACTCMMID        81.295915
# ACTENMID        82.383191
# ACTMTMID        82.383191
# dtype: float64

# %%
percent_missing.sort_values(axis=0)[7:].mean()
# Out:
# 66.65687138799099

# %%
df_further_reduced = df_reduced.dropna()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_further_reduced.isnull(), cmap='viridis', yticklabels=False, cbar=False)
# Out:
# <AxesSubplot:>

# %%
df_further_reduced['ACT_AVG'] = df_further_reduced[['ACTCMMID', 'ACTENMID','ACTMTMID' ]].mean(axis=1)
# Out:
# <ipython-input-42-70caf5ef3292>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_further_reduced['ACT_AVG'] = df_further_reduced[['ACTCMMID', 'ACTENMID','ACTMTMID' ]].mean(axis=1)

# %%
df_further_reduced.head()
# Out:
#    UNITID  OPEID6                               INSTNM        CITY STABBR  \
# 0  100654    1002             Alabama A & M University      Normal     AL
# 1  100663    1052  University of Alabama at Birmingham  Birmingham     AL
# 3  100706    1055  University of Alabama in Huntsville  Huntsville     AL
# 4  100724    1005             Alabama State University  Montgomery     AL
# 5  100751    1051            The University of Alabama  Tuscaloosa     AL
#
#           ZIP              INSTURL  \
# 0       35762        www.aamu.edu/
# 1  35294-0110  https://www.uab.edu
# 3       35899          www.uah.edu
# 4  36104-0271        www.alasu.edu
# 5  35487-0100          www.ua.edu/
#
#                                               NPCURL  ADM_RATE_ALL  ACTCMMID  \
# 0  www.aamu.edu/admissions-aid/tuition-fees/net-p...        0.8986      18.0
# 1   https://uab.studentaidcalculator.com/survey.aspx        0.9211      25.0
# ...

# %%
# actual user data will be received from request data in "/recommendations" api route
mock_user_data = [
    {
        "ACTCMMID":
        18,
        "ACTENMID":
        17,
        "ACTMTMID":
        17,
        "ACT_AVG":
        17,
        "ADM_RATE_ALL":
        0.8986,
        "CITY":
        "Normal",
        "INSTNM":
        "Alabama A & M University",
        "INSTURL":
        "www.aamu.edu/",
        "NPCURL":
        "www.aamu.edu/admissions-aid/tuition-fees/net-price-calculator.html",
        "OPEID6":
        1002,
        "SAT_AVG_ALL":
        957,
        "STABBR":
        "AL",
        "UNITID":
        100654,
        "ZIP":
        35762
    },
    {
        "ACTCMMID":
        25,
        "ACTENMID":
        27,
        "ACTMTMID":
        23,
        "ACT_AVG":
        25,
        "ADM_RATE_ALL":
        0.9211,
        "CITY":
        "Birmingham",
        "INSTNM":
        "University of Alabama at Birmingham",
        "INSTURL":
        "https://www.uab.edu",
        "NPCURL":
        "https://uab.studentaidcalculator.com/survey.aspx",
        "OPEID6":
        1052,
        "SAT_AVG_ALL":
        1220,
        "STABBR":
        "AL",
        "UNITID":
        100663,
        "ZIP":
        "35294-0110"
    },
    {
        "ACTCMMID":
        25,
        "ACTENMID":
        27,
        "ACTMTMID":
        23,
        "ACT_AVG":
        25,
        "ADM_RATE_ALL":
        0.9211,
        "CITY":
        "Birmingham",
        "INSTNM":
        "University of Utah",
        "INSTURL":
        "https://www.uab.edu",
        "NPCURL":
        "https://uab.studentaidcalculator.com/survey.aspx",
        "OPEID6":
        1200,
        "SAT_AVG_ALL":
        1250,
        "STABBR":
        "AL",
        "UNITID":
        1663,
        "ZIP":
        "35294-0110"
    },
]

# %%
df_user_data = pd.DataFrame(mock_user_data)

# %%
df_user_data
# Out:
#    ACTCMMID  ACTENMID  ACTMTMID  ACT_AVG  ADM_RATE_ALL        CITY  \
# 0        18        17        17       17        0.8986      Normal
# 1        25        27        23       25        0.9211  Birmingham
# 2        25        27        23       25        0.9211  Birmingham
#
#                                 INSTNM              INSTURL  \
# 0             Alabama A & M University        www.aamu.edu/
# 1  University of Alabama at Birmingham  https://www.uab.edu
# 2                   University of Utah  https://www.uab.edu
#
#                                               NPCURL  OPEID6  SAT_AVG_ALL  \
# 0  www.aamu.edu/admissions-aid/tuition-fees/net-p...    1002          957
# 1   https://uab.studentaidcalculator.com/survey.aspx    1052         1220
# 2   https://uab.studentaidcalculator.com/survey.aspx    1200         1250
#
#   STABBR  UNITID         ZIP
# 0     AL  100654       35762
# 1     AL  100663  35294-0110
# 2     AL    1663  35294-0110

# %%
count = df_user_data['UNITID'].count()

# %%
# selecting relevant columns for K-means clustering
cols = "ACTCMMID ACTENMID ACTMTMID ACT_AVG ADM_RATE_ALL SAT_AVG_ALL".split()
df_user_data_reduced = df_user_data[cols]
df_user_data_reduced.head()
# Out:
#    ACTCMMID  ACTENMID  ACTMTMID  ACT_AVG  ADM_RATE_ALL  SAT_AVG_ALL
# 0        18        17        17       17        0.8986          957
# 1        25        27        23       25        0.9211         1220
# 2        25        27        23       25        0.9211         1250

# %%
def k_value(row_count):
    if row_count > 0 and row_count < 5:
        return 1
    else:
        return 5

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters = k_value(count))

# %%
kmeans.fit(df_user_data_reduced)
# Out:
# KMeans(n_clusters=1)

# %%
kmeans.cluster_centers_
# Out:
# array([[2.26666667e+01, 2.36666667e+01, 2.10000000e+01, 2.23333333e+01,
#         9.13600000e-01, 1.14233333e+03]])

# %%
cluster_center = pd.DataFrame(kmeans.cluster_centers_, columns=cols)

# %%
cluster_center
# Out:
#     ACTCMMID   ACTENMID  ACTMTMID    ACT_AVG  ADM_RATE_ALL  SAT_AVG_ALL
# 0  22.666667  23.666667      21.0  22.333333        0.9136  1142.333333

# %%
# reducing college data dimensions to same as dimensions of user data
# preparing for least distance calculations
df_college_data = df_further_reduced[cols]
df_college_data.head()
# Out:
#    ACTCMMID  ACTENMID  ACTMTMID    ACT_AVG  ADM_RATE_ALL  SAT_AVG_ALL
# 0      18.0      17.0      17.0  17.333333        0.8986        957.0
# 1      25.0      27.0      23.0  25.000000        0.9211       1220.0
# 3      28.0      30.0      27.0  28.333333        0.8087       1314.0
# 4      18.0      17.0      17.0  17.333333        0.9774        972.0
# 5      27.0      29.0      25.0  27.000000        0.5906       1252.0

# %%
from sklearn.metrics import pairwise_distances_argmin_min

# %%
recommendations = []

# %%
for closest in range(5):
    """
    find closest college to cluster center
    add that college to recommendations list
    drop that college from dataframe so that same one does not get recommended again
    """
    closest, _ = pairwise_distances_argmin_min(kmeans.cluster_centers_, df_college_data)
    recommendations.append(df_college_data.iloc[closest])
    df_college_data = df_college_data.drop(df_college_data.index[closest])

# %%
college_ids = []
for rec in recommendations:
    college_ids.append(rec.index)

# %%
result = []
for college_id in college_ids:
    result.append(df_further_reduced.loc[college_id])

# %%
result
# Out:
# [      UNITID  OPEID6                         INSTNM        CITY STABBR  \
#  4534  433660   32553  Florida Gulf Coast University  Fort Myers     FL
#
#               ZIP       INSTURL  \
#  4534  33965-6565  www.fgcu.edu
#
#                                                   NPCURL  ADM_RATE_ALL  \
#  4534  https://www2.fgcu.edu/financialaid/netpricecal...        0.6492
#
#        ACTCMMID  ACTENMID  ACTMTMID  SAT_AVG_ALL    ACT_AVG
#  4534      23.0      23.0      22.0       1143.0  22.666667  ,
#        UNITID  OPEID6                         INSTNM        CITY STABBR  \
#  4534  433660   32553  Florida Gulf Coast University  Fort Myers     FL
#
#               ZIP       INSTURL  \
#  4534  33965-6565  www.fgcu.edu
#
#                                                   NPCURL  ADM_RATE_ALL  \
#  4534  https://www2.fgcu.edu/financialaid/netpricecal...        0.6492
#
#        ACTCMMID  ACTENMID  ACTMTMID  SAT_AVG_ALL    ACT_AVG
# ...

# %%
res = []
for i in result:
    res.append(i.to_dict(orient='records')[0])

# %%
res
# Out:
# [{'UNITID': 433660,
#   'OPEID6': 32553,
#   'INSTNM': 'Florida Gulf Coast University',
#   'CITY': 'Fort Myers',
#   'STABBR': 'FL',
#   'ZIP': '33965-6565',
#   'INSTURL': 'www.fgcu.edu',
#   'NPCURL': 'https://www2.fgcu.edu/financialaid/netpricecalculator/npcalc.htm',
#   'ADM_RATE_ALL': 0.6492,
#   'ACTCMMID': 23.0,
#   'ACTENMID': 23.0,
#   'ACTMTMID': 22.0,
#   'SAT_AVG_ALL': 1143.0,
#   'ACT_AVG': 22.666666666666668},
#  {'UNITID': 433660,
#   'OPEID6': 32553,
#   'INSTNM': 'Florida Gulf Coast University',
#   'CITY': 'Fort Myers',
#   'STABBR': 'FL',
#   'ZIP': '33965-6565',
#   'INSTURL': 'www.fgcu.edu',
#   'NPCURL': 'https://www2.fgcu.edu/financialaid/netpricecalculator/npcalc.htm',
#   'ADM_RATE_ALL': 0.6492,
#   'ACTCMMID': 23.0,
#   'ACTENMID': 23.0,
#   'ACTMTMID': 22.0,
#   'SAT_AVG_ALL': 1143.0,
#   'ACT_AVG': 22.666666666666668},
#  {'UNITID': 156541,
#   'OPEID6': 1962,
#   'INSTNM': 'University of the Cumberlands',
#   'CITY': 'Williamsburg',
#   'STABBR': 'KY',
# ...
